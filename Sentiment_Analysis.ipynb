# %% [markdown]
# <a href="https://colab.research.google.com/github/Kunal-Varma/Sentiment_Analysis/blob/master/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# ...
#     100% |████████████████████████████████| 133kB 6.1MB/s
# ...

# %%
# !pip install twython
# Out:
# ...
#   Stored in directory: /root/.cache/pip/wheels/c2/b0/a3/5c4b4b87b8c9e4d99f1494a0b471f0134a74e5fb33d426d009
# Successfully built twython
# ...

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
#My Twitter API Authentication Variables
consumer_key = 'wfu8Fx7cjCLttepsUIftGdZmu'
consumer_secret = 'PzSuGEcUyTn6zmdhbXFRem2LR7FwC5Zcj8AkBEIAEOTH03DZ4k'
access_token = '2509766127-v4dcW0aFUYUXLv2TUJ8NI6Ebs7aM4LClkTDIarn'
access_token_secret = 'gm0ttIaZgbZG8tH2NPozL90GQRPo7yo6JGY36IKjw5LdW'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('artificial intelligence', count=200)


data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))


print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  RT @_digitalhealth: Tickets available for the ...
# 1  RT @freyduni: Artificial Intelligence and Mach...
# 2  IBM has the biggest #AI patent portfolio, with...
# 3  RT @Dev_Fadnavis: With the use of artificial i...
# 4  RT @RealBillBunting: The coming of an #Artific...
# 5  RT @LBS: "Artificial Intelligence can be used ...
# 6  RT @onmedicglobal: Artificial Intelligence in ...
# 7  1. AI takes on a children’s game - Now, artifi...
# 8  RT @peterxing: From Virtual Nurses To Drug Dis...
# 9  RT @7wData: 32 Artificial #Intelligence Startu...
# 2019-02-06 18:25:36

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
sid = SentimentIntensityAnalyzer()


listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT @_digitalhealth: Tickets available for the ...
# 1   RT @freyduni: Artificial Intelligence and Mach...
# 2   IBM has the biggest #AI patent portfolio, with...
# 3   RT @Dev_Fadnavis: With the use of artificial i...
# 4   RT @RealBillBunting: The coming of an #Artific...
# 5   RT @LBS: "Artificial Intelligence can be used ...
# 6   RT @onmedicglobal: Artificial Intelligence in ...
# 7   1. AI takes on a children’s game - Now, artifi...
# 8   RT @peterxing: From Virtual Nurses To Drug Dis...
# 9   RT @7wData: 32 Artificial #Intelligence Startu...
# 10  What’s Behind JPMorgan Chase’s Big Bet on Arti...
# 11  RT @kvsrinath: #Health #Startup #BigData - A c...
# 12  I'll admit - this stuff scares me: Advances in...
# 13  RT @JohnNosta: 32 Artificial Intelligence Star...
# 14  Driving better road safety with technology and...
# 15  RT @Sentifi_CH: 32 Artificial Intelligence Sta...
# ...
